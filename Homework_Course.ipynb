# %%
courses=["MATH101","PHYS101","CMPE150","CET101","AE101"]

class student(): 
    
    studentCourses=[]
    grades = {
        "midterm": 0,
        "final": 0,
        "project": 0 
    }
    def __init__(self):
        self.name="Berat Burak"
        self.surname="Tetik"
    
    def addcourses(self,courseid):
        if courses[courseid]  not in self.studentCourses:
            self.studentCourses.append(courses[courseid])
            courses.remove(courses[courseid])
        
    def numberofCourses(self,coursenumber):
        if coursenumber<3:
            return(print("You failed in class"))
        else:
            for i in range(0,coursenumber):
                printCourses()
                self.addcourses(int(input()))
                
    def selectCourse():
        print
                
                
def printCourses():
    for i in range(len(courses)):
        print(courses[i]+" "+"To take this course enter "+str(i))

        
        
myStudent=student()

incorrectEntries=0
numberofCourses=0


while incorrectEntries<3:
    name=input("Enter name:")
    surname=input("Enter surname:")
    if name==myStudent.name and surname==myStudent.surname:
        print("Welcome "+myStudent.name+" "+myStudent.surname)
        numberofCourses=int(input("How many courses do you want to take?: "))
        myStudent.numberofCourses(numberofCourses)
        print("Select course that you want to take an exam.")
        for i in range(len(myStudent.studentCourses)):
            print(myStudent.studentCourses[i]+" "+"Press "+str(i)+" to select.")
        input()
        myStudent.grades["midterm"]=int(input("Enter midterm grade: "))
        myStudent.grades["final"]=int(input("Enter final grade: "))
        myStudent.grades["project"]=int(input("Enter project grade: "))
        midtermGrade =  (myStudent.grades["midterm"]*3)/10
        finalGrade = (myStudent.grades["final"]*5)/10
        projectGrade = (myStudent.grades["project"]*2)/10
        total = midtermGrade + finalGrade + projectGrade
        total = round(total,2)
        if(total >= 90):
            print("AA")
        elif(70 < total <= 90):
            print("BB")
        elif(50 < total <= 70):
            print("CC")
        elif(30 < total <= 50):
            print("DD")
        elif(total <= 30):
            print("FF")
            print("You have failed")
        break
    else:
        incorrectEntries=incorrectEntries+1
        if incorrectEntries==3:
            print("Please try again later.")
        else:
            print("Remaining entries "+ str(3-incorrectEntries))
